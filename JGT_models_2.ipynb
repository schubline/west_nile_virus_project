# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
train_df = pd.read_csv('assets/master_clean_train.csv')
test_df = pd.read_csv('assets/master_clean_test.csv')

# %% [markdown]
# CSVs have had 'duplicate' rows removed.  Traps which contain > 50 mosquitoes get > 1 row.  These other rows are removed, without accounting for the extra mosquitos.

# %%
train_df.shape
# Out:
# (9686, 29)

# %%
test_df.shape
# Out:
# (116293, 28)

# %%
train_df.columns
# Out:
# Index(['date', 'address', 'block', 'street', 'trap', 'addressnumberandstreet',
#        'latitude', 'longitude', 'addressaccuracy', 'nummosquitos',
#        'wnvpresent', 'neighborhood', 'dtdate', 'species_culex_pipiens',
#        'species_culex_pipiens_restuans', 'species_culex_restuans',
#        'neighborhood_infection_category_high',
#        'neighborhood_infection_category_low',
#        'neighborhood_infection_category_medium',
#        'neighborhood_infection_category_none', 'park_score', 'daylight',
#        'avg_tavg', 'avg_preciptotal', 'avg_avgspeed', 'timelaggeddaylight',
#        'timelaggedtemperature', 'timelaggedprecipitation',
#        'timelaggedwindspeed'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['id', 'date', 'address', 'block', 'street', 'trap',
#        'addressnumberandstreet', 'latitude', 'longitude', 'addressaccuracy',
#        'neighborhood', 'dtdate', 'species_culex_pipiens',
#        'species_culex_pipiens_restuans', 'species_culex_restuans',
#        'neighborhood_infection_category_high',
#        'neighborhood_infection_category_low',
#        'neighborhood_infection_category_medium',
#        'neighborhood_infection_category_none', 'park_score', 'daylight',
#        'avg_tavg', 'avg_preciptotal', 'avg_avgspeed', 'timelaggeddaylight',
#        'timelaggedtemperature', 'timelaggedprecipitation',
#        'timelaggedwindspeed'],
#       dtype='object')

# %%
train_df
# Out:
#             date                                            address  block  \
# 0     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...     41
# 1     2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...     41
# 2     2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA     62
# 3     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA     79
# 4     2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA     79
# 5     2007-05-29   1500 West Webster Avenue, Chicago, IL 60614, USA     15
# 6     2007-05-29     2500 West Grand Avenue, Chicago, IL 60654, USA     25
# 7     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA     11
# 8     2007-05-29        1100 Roosevelt Road, Chicago, IL 60608, USA     11
# 9     2007-05-29   1100 West Chicago Avenue, Chicago, IL 60642, USA     11
# 10    2007-05-29    2100 North Stave Street, Chicago, IL 60647, USA     21
# 11    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA     22
# 12    2007-05-29    2200 North Cannon Drive, Chicago, IL 60614, USA     22
# 13    2007-05-29     2200 West 113th Street, Chicago, IL 60643, USA     22
# 14    2007-05-29     2200 West 113th Street, Chicago, IL 60643, USA     22
# 15    2007-05-29   1100 South Peoria Street, Chicago, IL 60608, USA     11
# 16    2007-05-29      1700 West 95th Street, Chicago, IL 60643, USA     17
# 17    2007-05-29      2200 West 89th Street, Chicago, IL 60643, USA     22
# 18    2007-05-29      2200 West 89th Street, Chicago, IL 60643, USA     22
# 19    2007-05-29       North Streeter Drive, Chicago, IL 60611, USA     53
# 20    2007-05-29       North Streeter Drive, Chicago, IL 60611, USA     53
# 12                  69.1875                 0.053103             9.652273
# 13                  69.1875                 0.053103             9.652273
# 14                  69.1875                 0.053103             9.652273
# 15                  69.1875                 0.053103             9.652273
# 16                  69.1875                 0.053103             9.652273
# 17                  69.1875                 0.053103             9.652273
# 18                  69.1875                 0.053103             9.652273
# 19                  69.1875                 0.053103             9.652273
# 20                  69.1875                 0.053103             9.652273
# 21                  69.1875                 0.053103             9.652273
# 22                  69.1875                 0.053103             9.652273
# 23                  69.1875                 0.053103             9.652273
# 24                  69.1875                 0.053103             9.652273
# 25                  71.0000                 0.080347             9.345455
# 26                  71.0000                 0.080347             9.345455
# 27                  71.0000                 0.080347             9.345455
# 28                  71.0000                 0.080347             9.345455
# 29                  71.0000                 0.080347             9.345455
# ...                     ...                      ...                  ...
# 9656                64.0625                 0.067500             8.631818
# 9657                64.0625                 0.067500             8.631818
# 9658                64.0625                 0.067500             8.631818
# 9659                64.0625                 0.067500             8.631818
# 9660                64.0625                 0.067500             8.631818
# 9661                64.0625                 0.067500             8.631818
# 9662                64.0625                 0.067500             8.631818
# 9663                64.0625                 0.067500             8.631818
# 9664                64.0625                 0.067500             8.631818
# 9665                64.0625                 0.067500             8.631818
# 9666                64.0625                 0.067500             8.631818
# 9667                64.0625                 0.067500             8.631818
# 9668                64.0625                 0.067500             8.631818
# 9669                64.0625                 0.067500             8.631818
# 9670                64.0625                 0.067500             8.631818
# 9671                64.0625                 0.067500             8.631818
# 9672                64.0625                 0.067500             8.631818
# 9673                64.0625                 0.067500             8.631818
# 9674                64.0625                 0.067500             8.631818
# 9675                64.0625                 0.067500             8.631818
# 9676                64.0625                 0.067500             8.631818
# 9677                64.0625                 0.067500             8.631818
# 9678                64.0625                 0.067500             8.631818
# 9679                64.0625                 0.067500             8.631818
# 9680                64.0625                 0.067500             8.631818
# 9681                64.0625                 0.067500             8.631818
# 9682                64.0625                 0.067500             8.631818
# 9683                64.0625                 0.067500             8.631818
# 9684                64.0625                 0.067500             8.631818
# 9685                64.0625                 0.067500             8.631818
#
# [9686 rows x 29 columns]

# %%
print('Accuracy for baseline model is {0:.3f}.'.format(1-train_df.wnvpresent.mean()))
# Out:
# Accuracy for baseline model is 0.948.

# %%
def balance_classes(train_df):
    pass

# %% [markdown]
# ### train on num mosqitos

# %%
X_train = train_df[['species_culex_pipiens',
       'species_culex_pipiens_restuans', 'species_culex_restuans','park_score', 'daylight',
       'avg_tavg', 'avg_preciptotal', 'avg_avgspeed', 'timelaggeddaylight',
       'timelaggedtemperature', 'timelaggedprecipitation',
       'timelaggedwindspeed']].values
y_train = train_df['nummosquitos'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)

# %%
linreg = LinearRegression()
#scores = cross_val_score(linreg, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
scores = cross_val_score(linreg, X_train_s, y_train, cv=5)

# %%
scores
# Out:
# array([-0.13967852, -0.00456464,  0.02529572, -0.08277466, -0.13917259])

# %%
linreg.fit(X_train_s, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.coef_
# Out:
# array([ 3.57859365,  5.05030279,  2.64909355, -0.6557118 , -0.14046113,
#         0.01307281, -0.49942524,  0.94152489,  1.17468407,  1.64016503,
#        -0.10051253,  0.09984468])

# %%
linreg.intercept_
# Out:
# 10.217117489159618

# %%
plt.plot(y_train, linreg.predict(X_train_s), '.', alpha=0.1)

# %%
train_df.corr().nummosquitos.sort_values()
# Out:
# neighborhood_infection_category_low      -0.138611
# species_culex_restuans                   -0.104139
# neighborhood_infection_category_none     -0.087358
# longitude                                -0.070677
# addressaccuracy                          -0.067985
# latitude                                 -0.056949
# block                                    -0.051793
# timelaggedwindspeed                      -0.047788
# park_score                               -0.046351
# neighborhood_infection_category_medium   -0.044718
# avg_preciptotal                          -0.007089
# timelaggedprecipitation                  -0.003188
# species_culex_pipiens                     0.006744
# avg_avgspeed                              0.032763
# daylight                                  0.057134
# avg_tavg                                  0.125844
# species_culex_pipiens_restuans            0.126568
# timelaggeddaylight                        0.149279
# timelaggedtemperature                     0.170776
# neighborhood_infection_category_high      0.194299
# wnvpresent                                0.248173
# nummosquitos                              1.000000
# Name: nummosquitos, dtype: float64

# %% [markdown]
# This looks like a bunch of crap to me.  Can't predict number of mosquitos

# %% [markdown]
# ### AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
import time

# %%
X_train = train_df[['species_culex_pipiens',
       'species_culex_pipiens_restuans', 'species_culex_restuans',
       'neighborhood_infection_category_high',
       'neighborhood_infection_category_low',
       'neighborhood_infection_category_medium',
       'neighborhood_infection_category_none', 'park_score', 'daylight',
       'avg_tavg', 'avg_preciptotal', 'avg_avgspeed', 'timelaggeddaylight',
       'timelaggedtemperature', 'timelaggedprecipitation',
       'timelaggedwindspeed']].values
y_train = train_df['wnvpresent'].values

# %% [markdown]
# Tell AdaBoost to weight classes with method 'balanced'

# %%
time_start = time.time()
ada = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(class_weight='balanced'))
ada_params = {
    'base_estimator__max_depth': [2,3,4,5],
    'n_estimators': [10, 20, 30, 50, 100, 200]
}
gs_ada = GridSearchCV(ada, param_grid=ada_params, scoring='roc_auc', cv=5)
gs_ada.fit(X_train, y_train)
print(gs_ada.best_score_)
print(gs_ada.best_params_)
print('Elapsed time is {0:.2E}s'.format(time.time()-time_start))
# Out:
# 0.5860479184822577
# {'base_estimator__max_depth': 4, 'n_estimators': 200}
# Elapsed time is 1.26E+02s

# %% [markdown]
# Tell AdaBoost to weight classes uniformly

# %%
time_start = time.time()
ada = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(class_weight=None))
ada_params = {
    'base_estimator__max_depth': [2,3,4,5],
    'n_estimators': [10, 20, 30, 50, 100, 200]
}
gs_ada = GridSearchCV(ada, param_grid=ada_params, scoring='roc_auc', cv=5)
gs_ada.fit(X_train, y_train)
print(gs_ada.best_score_)
print(gs_ada.best_params_)
print('Elapsed time is {0:.2E}s'.format(time.time()-time_start))
# Out:
# 0.5640943088053957
# {'base_estimator__max_depth': 4, 'n_estimators': 200}
# Elapsed time is 1.16E+02s

# %%
time_start = time.time()
ada = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(class_weight='balanced'))
ada_params = {
    'base_estimator__max_depth': [3,4,5,6],
    'n_estimators': [100,200,300,400,500,700,1000]
            }
gs_ada = GridSearchCV(ada, param_grid=ada_params, scoring='roc_auc', cv=5)
gs_ada.fit(X_train, y_train)
print(gs_ada.best_score_)
print(gs_ada.best_params_)
print('Elapsed time is {0:.2E}s'.format(time.time()-time_start))
# Out:
# 0.5532993380949174
# {'base_estimator__max_depth': 4, 'n_estimators': 100}
# Elapsed time is 9.70E+02s

# %%
pd.DataFrame(gs_ada.cv_results_).sort_values(by='mean_test_score')
# Out:
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\James\Anaconda3\envs\dsi\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score  \
# 8        0.316109         0.011478         0.448339          0.942398
# 1        0.163101         0.007589         0.461760          0.901774
# 7        0.235167         0.008588         0.463477          0.927920
# 2        0.249936         0.012277         0.464534          0.911851
# 9        0.529715         0.017867         0.474884          0.960403
# 0        0.084351         0.004388         0.476052          0.883767
# 6        0.108694         0.005091         0.482607          0.906794
# 10       1.128693         0.035930         0.487314          0.979319
# 12       0.138642         0.005686         0.493604          0.931157
# 18       0.150924         0.005087         0.495516          0.953199
# 5        1.667504         0.072070         0.497628          0.959126
# 4        0.809691         0.033442         0.502300          0.943653
# 3        0.417727         0.020765         0.505145          0.925711
# 11       2.233747         0.076359         0.513213          0.990519
# 20       0.461538         0.013575         0.516613          0.988964
# 19       0.309928         0.008584         0.517351          0.978941
# 14       0.396751         0.012281         0.522568          0.970503
# 23       3.072196         0.072668         0.525145          0.997236
# 22       1.576266         0.044924         0.528084          0.997236
# 13       0.263407         0.008883         0.528097          0.957935
# 21       0.787533         0.021364         0.529112          0.995900
# 15       0.682032         0.018465         0.543903          0.983754
# 16       1.301284         0.037328         0.549358          0.995126
# 17       2.667547         0.073164         0.558562          0.997234
#
#    param_base_estimator__max_depth param_n_estimators  \
# 8                                3                 30
# 1                                2                 20
# 7                                3                 20
# 2                                2                 30
# 9                                3                 50
# 0                                2                 10
# 6                                3                 10
# 10                               3                100
# 12                               4                 10
# 18                               5                 10
# 5                                2                200
# 4                                2                100
# 3                                2                 50
# 11                               3                200
# 20                               5                 30
# 19                               5                 20
# 14                               4                 30
# 23                               5                200
# 22                               5                100
# 13                               4                 20
# 21                               5                 50
# 15                               4                 50
# 16                               4                100
# 17                               4                200
#
#                                                params  rank_test_score  \
# 8   {'base_estimator__max_depth': 3, 'n_estimators...               24
# 1   {'base_estimator__max_depth': 2, 'n_estimators...               23
# 7   {'base_estimator__max_depth': 3, 'n_estimators...               22
# 2   {'base_estimator__max_depth': 2, 'n_estimators...               21
# 9   {'base_estimator__max_depth': 3, 'n_estimators...               20
# 0   {'base_estimator__max_depth': 2, 'n_estimators...               19
# 6   {'base_estimator__max_depth': 3, 'n_estimators...               18
# 10  {'base_estimator__max_depth': 3, 'n_estimators...               17
# 12  {'base_estimator__max_depth': 4, 'n_estimators...               16
# 18  {'base_estimator__max_depth': 5, 'n_estimators...               15
# 5   {'base_estimator__max_depth': 2, 'n_estimators...               14
# 4   {'base_estimator__max_depth': 2, 'n_estimators...               13
# 3   {'base_estimator__max_depth': 2, 'n_estimators...               12
# 11  {'base_estimator__max_depth': 3, 'n_estimators...               11
# 20  {'base_estimator__max_depth': 5, 'n_estimators...               10
# 19  {'base_estimator__max_depth': 5, 'n_estimators...                9
# 14  {'base_estimator__max_depth': 4, 'n_estimators...                8
# 23  {'base_estimator__max_depth': 5, 'n_estimators...                7
# 22  {'base_estimator__max_depth': 5, 'n_estimators...                6
# 13  {'base_estimator__max_depth': 4, 'n_estimators...                5
# 21  {'base_estimator__max_depth': 5, 'n_estimators...                4
# 15  {'base_estimator__max_depth': 4, 'n_estimators...                3
# 16  {'base_estimator__max_depth': 4, 'n_estimators...                2
# 17  {'base_estimator__max_depth': 4, 'n_estimators...                1
#
#     split0_test_score  split0_train_score       ...         split2_test_score  \
# 8            0.678210            0.930088       ...                  0.352321
# 1            0.658755            0.885988       ...                  0.344206
# 7            0.655298            0.914313       ...                  0.339630
# 2            0.652498            0.897115       ...                  0.303425
# 9            0.670074            0.950062       ...                  0.378294
# 0            0.620526            0.865611       ...                  0.348917
# 6            0.592750            0.893069       ...                  0.254025
# 10           0.692754            0.973481       ...                  0.396304
# 12           0.669963            0.916036       ...                  0.388211
# 18           0.707476            0.942719       ...                  0.416348
# 5            0.722427            0.949649       ...                  0.413594
# 4            0.711066            0.932788       ...                  0.404418
# 3            0.722147            0.912946       ...                  0.394512
# 11           0.718598            0.989137       ...                  0.429537
# 20           0.689356            0.986904       ...                  0.426802
# 19           0.691415            0.974409       ...                  0.441419
# 14           0.728965            0.960505       ...                  0.453815
# 23           0.735099            0.997270       ...                  0.416618
# 22           0.757798            0.997270       ...                  0.430157
# 13           0.716350            0.947030       ...                  0.442106
# 21           0.708584            0.995370       ...                  0.398239
# 15           0.736565            0.979043       ...                  0.454058
# 16           0.732016            0.993511       ...                  0.425554
# 17           0.739179            0.997268       ...                  0.452999
#
#     split2_train_score  split3_test_score  split3_train_score  \
# 8             0.943922           0.140910            0.947407
# 1             0.908685           0.199205            0.908448
# 7             0.929201           0.188845            0.933524
# 2             0.916320           0.217135            0.916664
# 9             0.960535           0.187342            0.963266
# 0             0.891825           0.219733            0.896377
# 6             0.911477           0.220169            0.912414
# 10            0.978785           0.240191            0.980969
# 12            0.935725           0.197108            0.937056
# 18            0.952458           0.244254            0.956426
# 5             0.957375           0.248355            0.963438
# 4             0.943969           0.183965            0.948454
# 3             0.928691           0.219090            0.929280
# 11            0.990025           0.236629            0.991291
# 20            0.989799           0.309995            0.990479
# 19            0.979226           0.288840            0.981404
# 14            0.972003           0.215049            0.975095
# 23            0.997369           0.245839            0.997414
# 22            0.997369           0.311748            0.997414
# 13            0.961778           0.192124            0.960840
# 21            0.996154           0.309815            0.996548
# 15            0.984493           0.251400            0.985799
# 16            0.995535           0.289967            0.995881
# 17            0.997369           0.334281            0.997414
#
#     split4_test_score  split4_train_score  std_fit_time  std_score_time  \
# 8            0.357402            0.965555      0.002481        0.000316
# 1            0.351974            0.931008      0.007430        0.000198
# 7            0.426353            0.952653      0.016649        0.000738
# 2            0.389662            0.941009      0.012977        0.001686
# 9            0.393878            0.979498      0.005991        0.000200
# 0            0.370256            0.911174      0.005509        0.000198
# 6            0.562658            0.934629      0.003661        0.000798
# 10           0.335368            0.990056      0.008873        0.002229
# 12           0.535553            0.956278      0.003449        0.001199
# 18           0.386087            0.970612      0.001885        0.000482
# 5            0.296781            0.979012      0.077015        0.005164
# 4            0.416961            0.967980      0.005372        0.000550
# 3            0.430060            0.954319      0.015867        0.002948
# 11           0.409850            0.995597      0.031597        0.007927
# 20           0.370147            0.993747      0.007112        0.001317
# 19           0.383491            0.988553      0.010583        0.000373
# 14           0.524534            0.985037      0.012157        0.000926
# 23           0.439847            0.997842      0.062696        0.001532
# 22           0.401882            0.997842      0.018203        0.007223
# 13           0.556629            0.976998      0.006927        0.001558
# 21           0.455278            0.997606      0.014938        0.003163
# 15           0.551642            0.991714      0.017930        0.000315
# 16           0.548998            0.997329      0.035228        0.001817
# 17           0.503363            0.997842      0.077949        0.003733
#
#     std_test_score  std_train_score
# 8         0.216603         0.014264
# 1         0.209373         0.019632
# 7         0.194013         0.015195
# 2         0.207458         0.018288
# 9         0.204613         0.011116
# 0         0.215666         0.020975
# 6         0.214506         0.017959
# 10        0.207574         0.006140
# 12        0.181913         0.016336
# 18        0.188715         0.010126
# 5         0.226046         0.011621
# 4         0.222377         0.014684
# 3         0.205674         0.017346
# 11        0.201418         0.002978
# 20        0.186998         0.003342
# 19        0.187524         0.006006
# 14        0.184368         0.009461
# 23        0.205041         0.000514
# 22        0.184042         0.000514
# 13        0.199228         0.012064
# 21        0.180301         0.001265
# 15        0.180989         0.005033
# 16        0.176760         0.001502
# 17        0.166607         0.000517
#
# [24 rows x 22 columns]

# %%
ada = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=3), n_estimators=30)
ada.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=30, random_state=None)

# %%
ada.feature_importances_
# Out:
# array([0.02982953, 0.03036123, 0.0329975 , 0.00225393, 0.01349937,
#        0.00962313, 0.00762229, 0.35532005, 0.01842025, 0.06083808,
#        0.04559938, 0.05421686, 0.08690435, 0.07409205, 0.06567495,
#        0.11274706])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)

# %%
X_train.shape
# Out:
# (9686, 16)

# %%
logreg = LogisticRegression()
scores = cross_val_score(logreg,X_train_s,y_train,scoring='roc_auc', cv=5)

# %%
scores
# Out:
# array([0.82081472, 0.86930909, 0.51293812, 0.48522876, 0.74400327])

# %%
np.mean(scores)
# Out:
# 0.6864587898205107

# %%
gs_params = {'C': np.logspace(-5,5,11), 'class_weight':[None, 'balanced'], 'penalty': ['l1', 'l2']}
gs = GridSearchCV(logreg, gs_params, scoring='roc_auc', cv=5)
gs.fit(X_train_s,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02,
#        1.e+03, 1.e+04, 1.e+05]), 'class_weight': [None, 'balanced'], 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
gs.best_score_
# Out:
# 0.6947170657371059

# %%
gs.best_params_
# Out:
# {'C': 1e-05, 'class_weight': 'balanced', 'penalty': 'l2'}

# %%
logreg = LogisticRegression(C=1e-5, class_weight='balanced', penalty='l2')
logreg.fit(X_train_s,y_train)
# Out:
# LogisticRegression(C=1e-05, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
logreg.coef_
# Out:
# array([[ 0.01044474,  0.00147075, -0.0097141 ,  0.00662049, -0.00601508,
#         -0.00034908, -0.0038419 , -0.00105562, -0.00979488,  0.00725116,
#         -0.00067778, -0.00296096,  0.00460744,  0.0070889 , -0.00822995,
#         -0.01245983]])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(class_weight='balanced')
scores = cross_val_score(rfc,X_train,y_train,scoring='roc_auc', cv=5)

# %%
scores
# Out:
# array([0.60683314, 0.57550785, 0.37313312, 0.10327342, 0.29831972])

# %%
np.mean(scores)
# Out:
# 0.3914134495080364

# %%
train_df.date = pd.to_datetime(train_df.date)

# %%
import datetime as dt

# %%
train_df['month'] = train_df.date.map(lambda d: d.month)

# %%
X_train = train_df[['species_culex_pipiens',
       'species_culex_pipiens_restuans', 'species_culex_restuans',
       'neighborhood_infection_category_high',
       'neighborhood_infection_category_low',
       'neighborhood_infection_category_medium',
       'neighborhood_infection_category_none', 'park_score', 'daylight',
       'avg_tavg', 'avg_preciptotal', 'avg_avgspeed', 'timelaggeddaylight',
       'timelaggedtemperature', 'timelaggedprecipitation',
       'timelaggedwindspeed', 'month']].values
y_train = train_df['wnvpresent'].values

# %%
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)

# %%
logreg = LogisticRegression(class_weight='balanced')
scores = cross_val_score(logreg,X_train_s,y_train,scoring='roc_auc', cv=5)

# %%
scores
# Out:
# array([0.79214658, 0.79601912, 0.53638897, 0.49038126, 0.65488017])

# %%
np.mean(scores)
# Out:
# 0.6539632217888924

# %% [markdown]
# Bootstrap the minority class

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(ratio='minority')

# %%
X_train_os, y_train_os = smote.fit_sample(X_train, y_train)

# %%
ss = StandardScaler()
X_train_os_s = ss.fit_transform(X_train_os)

# %%
logreg = LogisticRegression(class_weight='balanced')
scores = cross_val_score(logreg,X_train_os_s,y_train_os,scoring='roc_auc', cv=5)

# %%
scores
# Out:
# array([0.58060303, 0.66977724, 0.76775227, 0.79463472, 0.69525758])

# %%
np.mean(scores)
# Out:
# 0.701604967889167

# %%
np.mean(y_train_os)
# Out:
# 0.5

# %%
logreg.fit(X_train_os_s,y_train_os)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
logreg.coef_
# Out:
# array([[ 2.29129147,  2.36902268,  1.5013149 ,  0.31249717, -0.38790558,
#          0.131089  , -0.84101622, -0.13029964, -1.25390588,  0.15796594,
#         -0.08907447,  0.19836593,  1.40922001,  0.14548113, -0.23520537,
#         -0.16733777,  0.59167986]])

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_train, logreg.predict(ss.transform(X_train)))
# Out:
# 0.7404133404949806
